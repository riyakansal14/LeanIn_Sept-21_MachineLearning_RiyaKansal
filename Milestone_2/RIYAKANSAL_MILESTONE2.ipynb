# %% [markdown]
# # Read the data from dataset 1, apply appropriate normalization and display in a data frame.

# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\dev💻\LeanIn\ML\dataset_1.csv')
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# 5     27            58000          0
# 6     27            84000          0
# 7     32           150000          1
# 8     25            33000          0
# 9     35            65000          0
# 10    26            80000          0
# 11    26            52000          0
# 12    20            86000          0
# 13    32            18000          0
# 14    18            82000          0
# 15    29            80000          0
# 16    47            25000          1
# 17    45            26000          1
# 18    46            28000          1
# 19    48            29000          1
# 20    45            22000          1
# 21    47            49000          1
# 22    48            41000          1
# 23    45            22000          1
# ...

# %%
for column in df.columns:
    df[column] = (df[column] - df[column].min()) / (df[column].max() - df[column].min())    
print(df)
# Out:
#           Age  EstimatedSalary  Purchased
# 0    0.023810         0.029630        0.0
# 1    0.404762         0.037037        0.0
# 2    0.190476         0.207407        0.0
# 3    0.214286         0.311111        0.0
# 4    0.023810         0.451852        0.0
# 5    0.214286         0.318519        0.0
# 6    0.214286         0.511111        0.0
# 7    0.333333         1.000000        1.0
# 8    0.166667         0.133333        0.0
# 9    0.404762         0.370370        0.0
# 10   0.190476         0.481481        0.0
# 11   0.190476         0.274074        0.0
# 12   0.047619         0.525926        0.0
# 13   0.333333         0.022222        0.0
# 14   0.000000         0.496296        0.0
# 15   0.261905         0.481481        0.0
# 16   0.690476         0.074074        1.0
# 17   0.642857         0.081481        1.0
# 18   0.666667         0.096296        1.0
# 19   0.714286         0.103704        1.0
# 20   0.642857         0.051852        1.0
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#           Age  EstimatedSalary  Purchased
# 0    0.023810         0.029630        0.0
# 1    0.404762         0.037037        0.0
# 2    0.190476         0.207407        0.0
# 3    0.214286         0.311111        0.0
# 4    0.023810         0.451852        0.0
# 5    0.214286         0.318519        0.0
# 6    0.214286         0.511111        0.0
# 7    0.333333         1.000000        1.0
# 8    0.166667         0.133333        0.0
# 9    0.404762         0.370370        0.0
# 10   0.190476         0.481481        0.0
# 11   0.190476         0.274074        0.0
# 12   0.047619         0.525926        0.0
# 13   0.333333         0.022222        0.0
# 14   0.000000         0.496296        0.0
# 15   0.261905         0.481481        0.0
# 16   0.690476         0.074074        1.0
# 17   0.642857         0.081481        1.0
# 18   0.666667         0.096296        1.0
# 19   0.714286         0.103704        1.0
# 20   0.642857         0.051852        1.0
# ...

# %% [markdown]
# # Read data from dataset 2, apply appropriate data pre processing techniques and store the data in a SQLite file. Display the SQLite file.

# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\dev💻\LeanIn\ML\dataset_2.csv')

# %%
df
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                    39.0
# 1             2    Male  21.0                15.0                    81.0
# 2             3  Female  20.0                16.0                     6.0
# 3             4  Female  23.0                16.0                    77.0
# 4             5  Female  31.0                17.0                    40.0
# 5             6  Female   NaN                17.0                    76.0
# 6             7  Female  35.0                18.0                     6.0
# 7             8  Female  23.0                18.0                    94.0
# 8             9    Male  64.0                19.0                     3.0
# 9            10  Female  30.0                19.0                    72.0
# 10           11    Male  67.0                19.0                    14.0
# 11           12  Female  35.0                19.0                    99.0
# ...

# %%
df.isnull()
# Out:
#      CustomerID  Genre    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False  False  False               False                   False
# 1         False  False  False               False                   False
# 2         False  False  False               False                   False
# 3         False  False  False               False                   False
# 4         False  False  False               False                   False
# 5         False  False   True               False                   False
# 6         False  False  False               False                   False
# 7         False  False  False               False                   False
# 8         False  False  False               False                   False
# 9         False  False  False               False                   False
# 10        False  False  False               False                   False
# 11        False  False  False               False                   False
# ...

# %%
newdf = df.dropna()

# %%
newdf
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                    39.0
# 1             2    Male  21.0                15.0                    81.0
# 2             3  Female  20.0                16.0                     6.0
# 3             4  Female  23.0                16.0                    77.0
# 4             5  Female  31.0                17.0                    40.0
# 6             7  Female  35.0                18.0                     6.0
# 7             8  Female  23.0                18.0                    94.0
# 8             9    Male  64.0                19.0                     3.0
# 9            10  Female  30.0                19.0                    72.0
# 10           11    Male  67.0                19.0                    14.0
# 11           12  Female  35.0                19.0                    99.0
# 12           13  Female  58.0                20.0                    15.0
# ...

# %%
import sqlite3
#creating database
conn = sqlite3.connect('spending_analysis.sqlite')
cur = conn.cursor()

# %%
#Creating table in database
cur.execute('DROP TABLE IF EXISTS SPENDING_ANALYSIS')
cur.execute('''CREATE TABLE SPENDING_ANALYSIS (
CUSTOMERID INTEGER PRIMARY KEY,
GENRE TEXT,
AGE INTEGER,
Annual_Income INTEGER,
Spending_Score INTEGER)''')
print("TABLE CREATED SUCCESSFULLY.")
# Out:
# TABLE CREATED SUCCESSFULLY.

# %%
for row in df.itertuples():
    cur.execute('''INSERT INTO SPENDING_ANALYSIS (CUSTOMERID, GENRE, AGE, Annual Income (k$), Spending_Score) VALUES(?,?,?,?,?)''', (row.CustomerID, row.Genre, row.Age, row.Annual Income (k$), row.Spending_Score))
conn.commit()
cur.close()
print("Records inserted successfully.")
# Out:
#   File "<ipython-input-19-0ea68d83cbc3>", line 2
#     cur.execute('''INSERT INTO SPENDING_ANALYSIS (CUSTOMERID, GENRE, AGE, Annual Income (k$), Spending_Score) VALUES(?,?,?,?,?)''', (row.CustomerID, row.Genre, row.Age, row.Annual Income (k$), row.Spending_Score))
#                                                                                                                                                                                     ^
# SyntaxError: invalid syntax
